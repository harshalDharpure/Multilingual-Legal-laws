# %%
from transformers import  AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, TrainingArguments, DataCollatorForLanguageModeling
from sklearn.model_selection import train_test_split
from datasets import DatasetDict, Dataset
import pandas as pd
import numpy as np
import warnings
import logging
import random
import torch
import json
import yaml
import os
import json
import torch
from transformers import pipeline
from sklearn.metrics import accuracy_score
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import ollama

warnings.filterwarnings("ignore")

with open('config.yaml', 'r') as file:
    config = yaml.safe_load(file)
def seed_everything(seed: int):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(42)





data_file = config['actual_data']
data_list = []
with open(data_file, 'r', encoding='utf-8') as df:
    for line in df:
        data_list.append(json.loads(line))

judge_file = "judge1.jsonl"
judge_data_list = []
with open(judge_file, 'r', encoding='utf-8') as df:
    for line in df:
        judge_data_list.append(json.loads(line))

# %%
def get_dict_from_path(path ,key):
    contexts_file=path
    context_dict = {}
    with open(contexts_file, 'r', encoding='utf-8') as cf:
        for line in cf:
            entry = json.loads(line)
            question = entry.get('Question')
            retrieved_context = entry.get(key)
            if question and retrieved_context:
                context_dict[question] = retrieved_context
    return context_dict 



contexts_file = "rag.xlsx"
context_df = pd.read_excel(contexts_file)

if 'Question' not in context_df.columns or 'retrieved_context' not in context_df.columns:
    raise ValueError("Excel file must contain 'Question' and 'retrieved_context' columns.")

# Build the dictionary
rag_dict = dict(zip(context_df['Question'], context_df['retrieved_context']))

# %%
defense_dict=get_dict_from_path("Defense.jsonl","Defense")
critique_dict=get_dict_from_path("Critique.jsonl","Critique")
pretrained_model_reasoning=get_dict_from_path("result_qwen7b_main_architecture05032025.jsonl","main_model_reasoning")

# %%
len(judge_data_list)
# Out:
# 937

# %%
question_to_data = {item["Question"]: item for item in data_list}

# %%
def get_data_entry(question, judge_data):
    # Start with a copy of the matching entry from question_to_data
    data = question_to_data[question].copy()
    
    # Remove unwanted keys if they exist
    data.pop("Correct Answer", None)
    data.pop("Reasoning", None)
    data.pop("Passage", None)
    
    # Add additional fields
    data['rag'] = rag_dict.get(question, None)
    data['main_model_reasoning'] = pretrained_model_reasoning.get(question, None)
    data['Critique'] = critique_dict.get(question, None)
    data['Defense'] = defense_dict.get(question, None)
    
    # Copy over any additional keys from judge_data that are not already in data
    for key, value in judge_data.items():
        if key not in data:
            data[key] = value

    return data

# %%
question=judge_data_list[0]["Question"]
temp=get_data_entry(question,judge_data_list[0])

# %%
temp
# Out:
# {'Question': "What legal actions should the authorities consider based on the specific allegations of assault highlighted in the passage, particularly concerning the victim's age and the nature of the crimes?",
#  'A': 'Authorities should only provide counseling to the victim and not pursue legal actions.',
#  'B': 'Authorities must take immediate legal action to investigate the allegations as the victim is a minor and the offenses fall under serious criminal categories.',
#  'C': 'The authorities have a duty to dismiss the allegations immediately due to political involvement.',
#  'D': 'Legal action can be postponed until the victim is older.',
#  'rag': "when claim of\noffence; the court shall make an inquiry,take such evidence asmay be necessary (but\njuvenility is\nraised before not anaffidavit) so asto determine the age of such person, and shall record afinding\nany court. whether theperson isajuvenile orachild or not, stating his age asnearly as may be:\nProvided that aclaim ofjuvenility mayberaised before anycourt and itshallbe\nrecognised at any stage, even after final disposal ofthe case, and such claim shall be\nrelevant laws as such.\n49. Presumption and determination of age.- (1) Where it appears to a competent authority that\nperson brought before it under any of the provisions of this Act (otherwise than for the purpose of\ngiving evidence) is a juvenile or the child, the competent authority shall make due inquiry so as to\nthe age of that person and for that purpose shall take such evidence as may be necessary (but\ndirections.\n18. (1) Where a Board is satisfied on inquiry that a child irrespective of age has Orders\ncommitted a petty offence, or a serious offence, or a child below the age of sixteen years has regarding\nchild found to\ncommitted a heinous offence, then, notwithstanding anything contrary contained in any\nbe in conflict\nother law for the time being in force, and based on the nature of offence, specific need for\nwith law.\ncomplainant or child victim and subsequent to the completion of investigation, copy of report of investigation\nand other relevant documents shall be handed over to the complainant or any person authorised to act on\nhis behalf.\n(9) No accused or suspected accused shall be brought in contact with the child and where the victim\nand the person in conflict with law are both children, they shall not be brought in contact with each other.\n(10) The Special Juvenile Police Unit shall have a list of:\n(4) The Person-in-charge may deal with the violation appropriately giving due consideration to the\nrecommendation of the Children’s Committee and the safety and dignity of the child.\n(5) The Person-in-charge may seek the assistance of the counsellor or the Child Welfare Officer or\nCase Worker, any non-governmental organisation associated with the Child Care Institution in dealing with\nthe situation.\n(vii) Whether the child has been provided any compensation? Yes/ No. If yes, please\nspecify…………………………\n26. If the child is a victim of abuse including sexual abuse: (This may be relevant for both child in conflict\nwith law and child in need of care and protection, as the case may be)\n(i) Whether the child has been provided counselling?............................\n(ii) Whether any action has been taken against such offender/perpetrator? If Yes, Please\nspecify………………………………………….\n(vii) Whether the child has been provided any compensation? Yes/ No. If yes, please\nspecify…………………………\n26. If the child is a victim of abuse including sexual abuse: (This may be relevant for both child in conflict\nwith law and child in need of care and protection, as the case may be)\n(i) Whether the child has been provided counselling?............................\n(ii) Whether any action has been taken against such offender/perpetrator? If Yes, Please\nspecify………………………………………….\nor criminal intent up to the age of eighteen years.\n(b) The juvenile’s or juvenile’s in conflict with law or child's right to presumption of innocence\nshall be respected throughout the process of justice and protection, from the initial contact to\nalternative care, including aftercare.\n(c) Any unlawful conduct of a juvenile or a child or a juvenile in conflict with law which is done\nfor survival, or is due to environmental or situational factors or is done under control of adults, or\ncease to be a\nnotwithstanding anything contained in this Act or in any other law for the time being in\nchild during\nforce, the inquiry may be continued by the Board and orders may be passed in respect of\nprocess of\nsuch person as if such person had continued to be a child. inquiry.\ ...
#  'main_model_reasoning': "The context emphasizes that when a child (victim) is alleged to have committed a serious offense, the authorities must take immediate legal action to investigate the allegations. This is evident from the provision stating that if a child is alleged to have committed a 'heinous offence' or 'serious offence,' the Board must conduct a preliminary assessment and take appropriate action. Additionally, the passage highlights the need for immediate legal action when a child is involved, especially considering the seriousness of the offenses mentioned.",
#  'Critique': "Critical Evaluation:\n\nThe initial answer and reasoning seem to be based on a correct interpretation of the relevant provisions in the context. However, there are a few areas where the reasoning could be challenged or improved:\n\n1.  **Immediate Legal Action**: The context emphasizes the need for immediate legal action when a child is alleged to have committed a serious offense. However, it does not explicitly state that the authorities must take immediate legal action without considering other factors. For instance, the context mentions that the Board may conduct a preliminary assessment to determine the child's mental and physical capacity to commit the offense (Section 15). This suggests that the authorities may need to consider the child's circumstances before taking immediate legal action.\n\n2.  **Serious Criminal Categories**: The context mentions that if a child is alleged to have committed a 'heinous offence' or'serious offence,' the Board must conduct a preliminary assessment and take appropriate action. However, it does not explicitly define what constitutes a 'heinous offence' or'serious offence.' Therefore, it is essential to consider the specific circumstances of the case and the nature of the offense before determining whether it falls under the serious criminal categories.\n\n3.  **Age Determination**: The context emphasizes the importance of age determination in cases involving children. However, it does not explicitly state that the authorities must determine the child's age before taking legal action. In fact, the context mentions that the Board may proceed with the inquiry without waiting for further confirmation of the child's age (Section 14). This suggests that the authorities may need to consider other factors, such as the child's physical appearance or documents, before determining their age.\n\n4.  **Legal Aid and Counseling**: The context mentions that the Board shall provide legal aid and counseling to the child (Section 14). However, it does not explicitly state that the authorities must provide counseling to the victim. Therefore, it is essential to consider the specific circumstances of the case and the needs of the victim before determining the appropriate course of action.\n\n5.  **Political Involvement**: The context does not explicitly address the issue of political involvement. However, it is essential to consider the potential impact of political involvement on the case and the child's rights.\n\nIn conclusion, while the initial answer and reasoning seem to be based on a correct interpretation of the relevant provisions, there are areas where the reasoning could be challenged or improved. It is essential to consider the specific circumstances of the case, the nature of the offense, and the child's rights before determining the appropriate course of action.\n\n**Alternative Answer:**\nAuthorities should take a balanced approach, considering both the need for immediate legal action and the child's circumstances, before determining the appropriate course of action.\n\n**Alternative Reasoning:**\nThe context emphasizes the need for a balanced approach when dealing with cases involving children. While immediate legal action may be necessary in some cases, it is essential to consider the child's circumstances, including their mental and physical capacity to commit the offense, before determining the appropriate course of action. The authorities should also provide legal aid and counseling to the child, as mentioned in Section 14, to ensure that their rights are protected.\n\n**Additional Considerations:**\n\n*   The authorities should consider the potential impact of political involvement on the case and the child's rights.\n*   The context mentions that the Board may proceed with the inquiry without waiting for further confirmation of the child's age (Section 14). Therefore, the authorities may need to consider other factors, such as the child's physical appearance or documents,  ...
#  'Defense': 'The initial answer and reasoning are based on a correct interpretation of the relevant provisions in the context, but there are areas where the reasoning could be challenged or improved. Let\'s analyze each critique point and provide a strengthened version of the answer:\n\n### 1. Immediate Legal Action vs. Balancing Approach\nCritique:\nThe initial answer suggests immediate legal action is required because a child is alleged to have committed a "serious offence." However, the context indicates that immediate action may not always be necessary, as the Board may conduct a preliminary assessment to determine the child\'s age and capacity to commit the offense.\n\nDefense:\nWhile immediate action is crucial, the initial answer correctly points out that the authorities should consider the child\'s circumstances, including their mental and physical capacity to commit the offense. The balance between urgency and thoroughness is important. Therefore, the revised answer should emphasize a balanced approach, acknowledging that immediate action may sometimes be warranted but should not preclude careful evaluation.\n\n### 2. Serious Criminal Categories\nCritique:\nThe initial answer states that serious criminal categories must be considered, but it lacks clarity on how the seriousness of the offenses affects the timing of legal action.\n\nDefense:\nThe revised answer should clarify that the classification of offenses as "heinous" or "serious" by the Board determines whether immediate action is needed. For offenses classified as serious, the authorities should take immediate legal action to protect the child. For less serious offenses, a more cautious approach might be acceptable, pending additional assessments.\n\n### 3. Age Determination\nCritique:\nThe initial answer notes the need for age determination but does not elaborate on the criteria used. Clarification is needed on how the Board determines the child\'s age.\n\nDefense:\nThe revised answer should highlight that age determination involves assessing the child\'s physical appearance and availability of documentation. The Board should prioritize accuracy and completeness in this process. Immediate action may still be justified despite incomplete age determinations.\n\n### 4. Political Involvement\nCritique:\nThe initial answer touches on political involvement but does not fully explain its implications or relevance to the legal action.\n\nDefense:\nThe revised answer should address the potential impact of political involvement, noting that while immediate action is critical, the child\'s rights must be safeguarded. Politically motivated interference should not delay necessary investigations.\n\n### 5. Additional Factors\nCritique:\nThe initial answer omits discussing other considerations like political involvement and psychological support for the child.\n\nDefense:\nThe revised answer should incorporate these factors, emphasizing that the child\'s rights, the seriousness of the offense,',
#  'Winner': 'Challenger',
#  'Correct Answer': 'Authorities must take immediate legal action to investigate the allegations as the victim is a minor and the offenses fall under serious criminal categories.',
#  'Judgement': "The challenger's argument was stronger because it prioritized both the urgency of the situation and the child's protection, showing a more comprehensive understanding of the issue at hand. This approach aligns with legal principles emphasizing swift action in cases involving minors and severe offenses.",
#  'final_reasoning': "Considering the severity of the crimes alleged and the victim's age, the most appropriate course of action is to take immediate legal action while ensuring the child receives necessary support. This balance between urgency and compassion ensures justice for both the child and society as a whole."}

# %%
cov_system_prompt = """You are a legal verification expert tasked with validating and, if needed, correcting the answer provided by a legal QA model.

Your task involves:
1. Reviewing the question, model answer, reasoning, and retrieved legal context.
2. Judging the validity of the model's answer using the context.
3. Correcting the answer if it is wrong and explaining your correction.
4. Performing legal fallacy checks before verdict:
   - Statute applicability (age thresholds; POCSO consent irrelevance; Sec 19 mandatory reporting; Sec 33(7) privacy)
   - Element coverage (assault vs penetrative; aggravated conditions)
   - Temporal/forum errors (anticipatory bail post-arrest; wrong forum/procedure)
5. Following a strict verification format including a structured fallacy report.
"""

# %%
def generate_cov_content(data):
    question = data.get('Question', '')
    options = {
        'A': data.get('A', ''),
        'B': data.get('B', ''),
        'C': data.get('C', ''),
        'D': data.get('D', '')
    }
    chosen_option = data.get('Correct Answer', '')
    main_model_reasoning=data.get('main_model_reasoning','')

    rag_context = data.get('rag', '')
    winner = data.get('Winner', 'N/A')
    judgement = data.get('Judgement', '')
    final_reasoning = data.get('final_reasoning', '')
    critique = data.get('Critique', '')
    defense = data.get('Defense', '')
    critique_debate = f"{critique}\n\n{defense}\n\n{judgement}\n\n{final_reasoning}"

    content = f"""
1️⃣ Review the following:

- **Question:** {question}

- **Options:**
A: {options['A']}
B: {options['B']}
C: {options['C']}
D: {options['D']}

- **Chosen Option Content (from the model):**
{chosen_option}

-**Model Reasoning:**
{main_model_reasoning}

- **Retrieved Legal Context:**
{rag_context}

- **Winner of Debate:** {winner}

- **Model Reasoning (Judgement + Final Reasoning):**
{judgement}\n\n{final_reasoning}

- **Critique + Defense + Judgement + Reasoning:**
{critique_debate}

---

2️⃣ **Chain of Verification Steps:**

✅ **Step 1:** Analyze the retrieved legal context and determine how each part relates to the question and each option.

✅ **Step 2:** For **each option (A/B/C/D)**:
- Clearly state whether the option is **Supported** or **Not Supported** based on the retrieved context.
- Provide 1-2 sentences justifying your verdict for that option.

✅ **Step 3:** Run legal fallacy checks and list:
- Misapplication of statutes / inapplicable provisions
- Missing required elements relative to the chosen statute
- Procedural/temporal/forum errors

✅ **Step 4:** Verify the model’s chosen option:
- Does the retrieved context fully support it?
- Is the reasoning legally sound and complete?
- If **Defender won**, focus on validating and strengthening the Defender’s argument.
- If **Challenger won**, focus on exposing flaws and showing why the Challenger succeeded.

✅ **Step 5:** **Final Correction:**
- If the model’s original answer is correct, reaffirm it confidently.
- If the model’s answer is incorrect, identify the **correct option** (from A/B/C/D), provide the full text of the correct option, and explain **why it is correct**.

---

**Your Output Format:**

- **Verification Verdict for Each Option:**
    - Option A: <Supported/Not Supported> - <short justification>
    - Option B: <Supported/Not Supported> - <short justification>
    - Option C: <Supported/Not Supported> - <short justification>
    - Option D: <Supported/Not Supported> - <short justification>

- **Fallacy Report:**
    - misapplication: [ ... ]
    - missing_elements: [ ... ]
    - procedural_errors: [ ... ]

- **Verification of Chosen Option:**
    - Verdict: <Fully Verified / Partially Verified / Not Verified>
    - Detailed Verification Reasoning: <step-by-step reasoning>

- **Final Correct Answer:**
    - Correct Option: <correct_option full text>
    - Final Reasoning: <detailed reasoning why this is the correct option>
"""
    return  content

# %%
json_system_prompt = '''
You are a strict JSON datapoint creator.
Your response must be in strict JSON format as shown below:
```json
{
  "Verification": {
    "option_verdicts": {
      "A": "Supported | Not Supported",
      "B": "Supported | Not Supported",
      "C": "Supported | Not Supported",
      "D": "Supported | Not Supported"
    },
    "fallacy_report": {
      "misapplication": ["..."],
      "missing_elements": ["..."],
      "procedural_errors": ["..."]
    },
    "chosen_option_verdict": "Fully Verified | Partially Verified | Not Verified",
    "verification_reasoning": "..."
  },
  "Correct Answer": "<Write the full content of the correct option>",
  "final_reasoning": "<Detailed reasoning for the correct option>"
}
```
Output must be strictly valid JSON.
Note: Do not mention the option letter; include full text for Correct Answer only.
'''

# %%
def extract_nested_braces(s):
    # s = s.replace('"','')
    s += "}"
    stack = []
    start = -1
    result = []
    # print(s)
    for i, char in enumerate(s):
        if char == '{':
            if not stack:
                start = i
            stack.append(char)
        elif char == '}':
            if stack:
                stack.pop()
                if not stack:
                    result.append(s[start:i+1])
    return result[0] if result else None

def string_to_dict(json_string):
    try:
        # Parse the JSON string into a dictionary
        return json.loads(json_string)
    except json.JSONDecodeError as e:
        raise ValueError(f"Invalid JSON string: {e}")




def model_output( data_entry):
    content = generate_cov_content(data_entry)
    response = ollama.chat(
        model='llama3.1:8b',  # or any model you've pulled, e.g., 'mistral', 'llama2', etc.
        messages=[
            {'role': 'system', 'content': cov_system_prompt},
            {'role': 'user', 'content': content},
        ]
    )
    json_output=response['message']['content']
    response = ollama.chat(
        model='llama3.1:8b',  # or any model you've pulled, e.g., 'mistral', 'llama2', etc.
        messages=[
            {'role': 'system', 'content': json_system_prompt},
            {'role': 'user', 'content': json_output},
        ]
    )
    judge_output=response['message']['content']
    result = string_to_dict(extract_nested_braces(judge_output))
    # print(result)
    return result

# %%
length=len(judge_data_list)
while(length<1950):
    result_log_path = 'cov.jsonl'  # ✅ Path to save the results
    print("HII")

    # 🔄 Load existing results if available
    if os.path.isfile(result_log_path):
        with open(result_log_path, 'r', encoding='utf-8') as file:
            output_log = [json.loads(line) for line in file]
    else:
        output_log = []

    # 🛑 Create a set of already processed questions to avoid duplicates
    processed_questions = set(entry["Question"] for entry in output_log)
    i=len(processed_questions)
    for judge_item in judge_data_list:
        question = judge_item["Question"]
        if question in processed_questions:
            i+=1
            continue
        try:
            compact_data=get_data_entry(question,judge_item)
            result=model_output(compact_data)
            result['Question']=question
            output_log.append(result)
            with open(result_log_path, 'a', encoding='utf-8') as file:
                file.write(json.dumps(result, ensure_ascii=False) + '\n')

            print(f"✅ Data point {i} processed and saved.")
            i += 1
        except Exception as e:
            print(f"⚠️ Error processing question: {question}")
            print(f"Exception: {e}")
# Out:
# HII
# ✅ Data point 0 processed and saved.
# ✅ Data point 1 processed and saved.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 23
#      21 try:
#      22     compact_data=get_data_entry(question,judge_item)
# ---> 23     result=model_output(compact_data)
#      24     result['Question']=question
#      25     output_log.append(result)
#
# Cell In[56], line 32, in model_output(data_entry)
#      30 def model_output( data_entry):
#      31     content = generate_cov_content(data_entry)
# ---> 32     response = ollama.chat(
#      33         model='llama3.1:8b',  # or any model you've pulled, e.g., 'mistral', 'llama2', etc.
#      34         messages=[
#      35             {'role': 'system', 'content': cov_system_prompt},
#      36             {'role': 'user', 'content': content},
#      37         ]
#      38     )
#      39     json_output=response['message']['content']
#      40     response = ollama.chat(
#      41         model='llama3.1:8b',  # or any model you've pulled, e.g., 'mistral', 'llama2', etc.
#      42         messages=[
#    (...)     45         ]
#      46     )
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/ollama/_client.py:333, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     289 def chat(
#     290   self,
#     291   model: str = '',
#    (...)    298   keep_alive: Optional[Union[float, str]] = None,
#     299 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     300   """
#     301   Create a chat response using the requested model.
#     302
#    (...)    331   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     332   """
# --> 333   return self._request(
#     334     ChatResponse,
#     335     'POST',
#     336     '/api/chat',
#     337     json=ChatRequest(
#     338       model=model,
#     339       messages=[message for message in _copy_messages(messages)],
#     340       tools=[tool for tool in _copy_tools(tools)],
#     341       stream=stream,
#     342       format=format,
#     343       options=options,
#     344       keep_alive=keep_alive,
#     345     ).model_dump(exclude_none=True),
#     346     stream=stream,
#     347   )
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/ollama/_client.py:178, in Client._request(self, cls, stream, *args, **kwargs)
#     174         yield cls(**part)
#     176   return inner()
# --> 178 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     116 def _request_raw(self, *args, **kwargs):
#     117   try:
# --> 118     r = self._client.request(*args, **kwargs)
#     119     r.raise_for_status()
#     120     return r
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/MTPharsh/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
